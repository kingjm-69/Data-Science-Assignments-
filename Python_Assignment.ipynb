# %% [markdown]
# Exercise 1: Prime Numbers
#
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
# Take input from user
num = int(input("Enter a number: "))

# Check if number is prime
if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print(f"{num} is not a Prime number.")
            break
    else:
        print(f"{num} is a Prime number.")
else:
    print(f"{num} is not a Prime number.")
# Out:
# Enter a number: 7
# 7 is a Prime number.

# %% [markdown]
# Exercise 2: Product of Random Numbers Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random

# Generate two random numbers
num1 = random.randint(1, 10)
num2 = random.randint(1, 10)

# Ask user for the product
print(f"What is the product of {num1} and {num2}?")
user_answer = int(input("Enter your answer: "))

# Check the answer
correct_answer = num1 * num2

if user_answer == correct_answer:
    print("✅ Correct! Well done.")
else:
    print(f"❌ Incorrect. The correct answer is {correct_answer}.")
# Out:
# What is the product of 4 and 9?
# Enter your answer: 8
# ❌ Incorrect. The correct answer is 36.

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers
#
# Write a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
# Printing squares of EVEN numbers from 100 to 200

for num in range(100, 201):
    if num % 2 == 0:   # condition for even numbers
        print(f"Square of {num} is {num**2}")
# Out:
# Square of 100 is 10000
# Square of 102 is 10404
# Square of 104 is 10816
# Square of 106 is 11236
# Square of 108 is 11664
# Square of 110 is 12100
# Square of 112 is 12544
# Square of 114 is 12996
# Square of 116 is 13456
# Square of 118 is 13924
# Square of 120 is 14400
# Square of 122 is 14884
# Square of 124 is 15376
# Square of 126 is 15876
# Square of 128 is 16384
# Square of 130 is 16900
# Square of 132 is 17424
# Square of 134 is 17956
# Square of 136 is 18496
# Square of 138 is 19044
# Square of 140 is 19600
# Square of 142 is 20164
# Square of 144 is 20736
# Square of 146 is 21316
# Square of 148 is 21904
# Square of 150 is 22500
# Square of 152 is 23104
# Square of 154 is 23716
# Square of 156 is 24336
# Square of 158 is 24964
# Square of 160 is 25600
# Square of 162 is 26244
# Square of 164 is 26896
# Square of 166 is 27556
# Square of 168 is 28224
# Square of 170 is 28900
# Square of 172 is 29584
# Square of 174 is 30276
# Square of 176 is 30976
# Square of 178 is 31684
# ...

# %% [markdown]
# Exercise 4: Hospital Billing System
#
# A hospital charges its patients based on the following:
#
# Room charges per day: ₹2,000
# Doctor consultation fee: ₹1,500
# Lab test charges: ₹300 per test
# Medicine charges: given
# Discount: 10% if total exceeds ₹10,000

# %%
# Given data
room_days = 4
room_charge_per_day = 2000
doctor_fee = 1500
lab_tests = 3
lab_test_cost = 300
medicine_charges = 2400

# Calculations
room_total = room_days * room_charge_per_day
lab_total = lab_tests * lab_test_cost

total_bill = room_total + doctor_fee + lab_total + medicine_charges

# Apply discount
if total_bill > 10000:
    discount = total_bill * 0.10
else:
    discount = 0

final_bill = total_bill - discount

# Output
print("Total Bill before discount:", total_bill)
print("Discount applied:", discount)
print("Final Bill to be paid:", final_bill)
# Out:
# Total Bill before discount: 12800
# Discount applied: 1280.0
# Final Bill to be paid: 11520.0
